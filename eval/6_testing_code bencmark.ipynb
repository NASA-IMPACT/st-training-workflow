# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from datasets import load_dataset


corpus = load_dataset("nasa-impact/nasa_repo_code_benchmark_v0.1", data_files="corpus.jsonl", split="train")
queries = load_dataset("nasa-impact/nasa_repo_code_benchmark_v0.1", data_files="queries.jsonl", split="train")

relevant_docs_data = load_dataset(
        "nasa-impact/nasa_repo_code_benchmark_v0.1",
        split="train",
        data_files="qrels/nasa_science_class_code_docstring_heldout.tsv",
    )
# Out:
# Using the latest cached version of the dataset since nasa-impact/nasa_repo_code_benchmark_v0.1 couldn't be found on the Hugging Face Hub
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from datasets import load_dataset
# ----> 4 corpus = load_dataset("nasa-impact/nasa_repo_code_benchmark_v0.1", data_files="corpus.jsonl", split="train")
#       5 queries = load_dataset("nasa-impact/nasa_repo_code_benchmark_v0.1", data_files="queries.jsonl", split="train")
#       7 relevant_docs_data = load_dataset(
#       8         "nasa-impact/nasa_repo_code_benchmark_v0.1",
#       9         split="train",
#      10         data_files="qrels/nasa_science_class_code_docstring_heldout.tsv",
#      11     )
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/datasets/load.py:2062, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2057 verification_mode = VerificationMode(
#    2058     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2059 )
#    2061 # Create a dataset builder
# -> 2062 builder_instance = load_dataset_builder(
#    2063     path=path,
#    2064     name=name,
#    2065     data_dir=data_dir,
#    2066     data_files=data_files,
#    2067     cache_dir=cache_dir,
#    2068     features=features,
#    2069     download_config=download_config,
#    2070     download_mode=download_mode,
#    2071     revision=revision,
#    2072     token=token,
#    2073     storage_options=storage_options,
#    2074     trust_remote_code=trust_remote_code,
#    2075     _require_default_config_name=name is None,
#    2076     **config_kwargs,
#    2077 )
#    2079 # Return iterable dataset in case of streaming
#    2080 if streaming:
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/datasets/load.py:1819, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1817 builder_cls = get_dataset_builder_class(dataset_module, dataset_name=dataset_name)
#    1818 # Instantiate the dataset builder
# -> 1819 builder_instance: DatasetBuilder = builder_cls(
#    1820     cache_dir=cache_dir,
#    1821     dataset_name=dataset_name,
#    1822     config_name=config_name,
#    1823     data_dir=data_dir,
#    1824     data_files=data_files,
#    1825     hash=dataset_module.hash,
#    1826     info=info,
#    1827     features=features,
#    1828     token=token,
#    1829     storage_options=storage_options,
#    1830     **builder_kwargs,
#    1831     **config_kwargs,
#    1832 )
#    1833 builder_instance._use_legacy_cache_dir_if_possible(dataset_module)
#    1835 return builder_instance
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/datasets/packaged_modules/cache/cache.py:124, in Cache.__init__(self, cache_dir, dataset_name, config_name, version, hash, base_path, info, features, token, repo_id, data_files, data_dir, storage_options, writer_batch_size, **config_kwargs)
#     122     config_kwargs["data_dir"] = data_dir
#     123 if hash == "auto" and version == "auto":
# --> 124     config_name, version, hash = _find_hash_in_cache(
#     125         dataset_name=repo_id or dataset_name,
#     126         config_name=config_name,
#     127         cache_dir=cache_dir,
#     128         config_kwargs=config_kwargs,
#     129         custom_features=features,
#     130     )
#     131 elif hash == "auto" or version == "auto":
#     132     raise NotImplementedError("Pass both hash='auto' and version='auto' instead")
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/datasets/packaged_modules/cache/cache.py:64, in _find_hash_in_cache(dataset_name, config_name, cache_dir, config_kwargs, custom_features)
#      56     cached_directory_paths = [
#      57         cached_directory_path
#      58         for cached_directory_path in glob.glob(os.path.join(cached_datasets_directory_path_root, "*", "*", "*"))
#      59         if os.path.isdir(cached_directory_path)
#      60     ]
#      61     available_configs = sorted(
#      62         {Path(cached_directory_path).parts[-3] for cached_directory_path in cached_directory_paths}
#      63     )
# ---> 64     raise ValueError(
#      65         f"Couldn't find cache for {dataset_name}"
#      66         + (f" for config '{config_id}'" if config_id else "")
#      67         + (f"\nAvailable configs in the cache: {available_configs}" if available_configs else "")
#      68     )
#      69 # get most recent
#      70 cached_directory_path = Path(sorted(cached_directory_paths, key=_get_modification_time)[-1])
#
# ValueError: Couldn't find cache for nasa-impact/nasa_repo_code_benchmark_v0.1 for config 'default-data_files=corpus.jsonl'
# Available configs in the cache: ['default-cc439393e5286621', 'default-cf5ca65c6f22a217', 'default-f68ba232d96db798']

# %%
relevant_docs_data
# Out:
# Dataset({
#     features: ['query-id', 'corpus-id', 'score'],
#     num_rows: 10274
# })

# %%
from transformers import AutoModel, AutoTokenizer

checkpoint = "Salesforce/codet5p-110m-embedding"
device = "cuda"  # for GPU usage or "cpu" for CPU usage

tokenizer = AutoTokenizer.from_pretrained(checkpoint, trust_remote_code=True)
model = AutoModel.from_pretrained(checkpoint, trust_remote_code=True).to(device)

inputs = tokenizer.encode("def print_hello_world():\tprint('Hello World!')", return_tensors="pt").to(device)
embedding = model(inputs)[0]
print(f'Dimension of the embedding: {embedding.size()[0]}, with norm={embedding.norm().item()}')
# Dimension of the embedding: 256, with norm=1.0
print(embedding)
# tensor([ 0.0185,  0.0229, -0.0315, -0.0307, -0.1421, -0.0575, -0.0275,  0.0501,
#          0.0203,  0.0337, -0.0067, -0.0075, -0.0222, -0.0107, -0.0250, -0.0657,
#          0.1571, -0.0994, -0.0370,  0.0164, -0.0948,  0.0490, -0.0352,  0.0907,
#         -0.0198,  0.0130, -0.0921,  0.0209,  0.0651,  0.0319,  0.0299, -0.0173,
#         -0.0693, -0.0798, -0.0066, -0.0417,  0.1076,  0.0597, -0.0316,  0.0940,
#         -0.0313,  0.0993,  0.0931, -0.0427,  0.0256,  0.0297, -0.0561, -0.0155,
#         -0.0496, -0.0697, -0.1011,  0.1178,  0.0283, -0.0571, -0.0635, -0.0222,
#          0.0710, -0.0617,  0.0423, -0.0057,  0.0620, -0.0262,  0.0441,  0.0425,
#         -0.0413, -0.0245,  0.0043,  0.0185,  0.0060, -0.1727, -0.1152,  0.0655,
#         -0.0235, -0.1465, -0.1359,  0.0022,  0.0177, -0.0176, -0.0361, -0.0750,
#         -0.0464, -0.0846, -0.0088,  0.0136, -0.0221,  0.0591,  0.0876, -0.0903,
#          0.0271, -0.1165, -0.0169, -0.0566,  0.1173, -0.0801,  0.0430,  0.0236,
#          0.0060, -0.0778, -0.0570,  0.0102, -0.0172, -0.0051, -0.0891, -0.0620,
#         -0.0536,  0.0190, -0.0039, -0.0189, -0.0267, -0.0389, -0.0208,  0.0076,
#         -0.0676,  0.0630, -0.0962,  0.0418, -0.0172, -0.0229, -0.0452,  0.0401,
#          0.0270,  0.0677, -0.0111, -0.0089,  0.0175,  0.0703,  0.0714, -0.0068,
#          0.1214, -0.0004,  0.0020,  0.0255,  0.0424, -0.0030,  0.0318,  0.1227,
#          0.0676, -0.0723,  0.0970,  0.0637, -0.0140, -0.0283, -0.0120,  0.0343,
#         -0.0890,  0.0680,  0.0514,  0.0513,  0.0627, -0.0284, -0.0479,  0.0068,
#         -0.0794,  0.0202,  0.0208, -0.0113, -0.0747,  0.0045, -0.0854, -0.0609,
#         -0.0078,  0.1168,  0.0618, -0.0223, -0.0755,  0.0182, -0.0128,  0.1116,
#          0.0240,  0.0342,  0.0119, -0.0235, -0.0150, -0.0228, -0.0568, -0.1528,
#          0.0164, -0.0268,  0.0727, -0.0569,  0.1306,  0.0643, -0.0158, -0.1070,
#         -0.0107, -0.0139, -0.0363,  0.0366, -0.0986, -0.0628, -0.0277,  0.0316,
#          0.0363,  0.0038, -0.1092, -0.0679, -0.1398, -0.0648,  0.1711, -0.0666,
#          0.0563,  0.0581,  0.0226,  0.0347, -0.0672, -0.0229, -0.0565,  0.0623,
#          0.1089, -0.0687, -0.0901, -0.0073,  0.0426,  0.0870, -0.0390, -0.0144,
#         -0.0166,  0.0262, -0.0310,  0.0467, -0.0164, -0.0700, -0.0602, -0.0720,
#         -0.0386,  0.0067, -0.0337, -0.0053,  0.0829,  0.1004,  0.0427,  0.0026,
#         -0.0537,  0.0951,  0.0584, -0.0583, -0.0208,  0.0124,  0.0067,  0.0403,
#          0.0091, -0.0044, -0.0036,  0.0524,  0.1103, -0.1511, -0.0479,  0.1709,
#          0.0772,  0.0721, -0.0332,  0.0866,  0.0799, -0.0581,  0.0713,  0.0218],
#        device='cuda:0', grad_fn=<SelectBackward0>)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_codet5p_embedding.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Salesforce/codet5p-110m-embedding:
# - configuration_codet5p_embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_codet5p_embedding.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Salesforce/codet5p-110m-embedding:
# - modeling_codet5p_embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Dimension of the embedding: 256, with norm=1.0
# tensor([ 0.0185,  0.0229, -0.0315, -0.0307, -0.1421, -0.0575, -0.0275,  0.0501,
#          0.0203,  0.0337, -0.0067, -0.0075, -0.0222, -0.0107, -0.0250, -0.0657,
#          0.1571, -0.0994, -0.0370,  0.0164, -0.0948,  0.0490, -0.0352,  0.0907,
#         -0.0198,  0.0130, -0.0921,  0.0209,  0.0651,  0.0319,  0.0299, -0.0173,
#         -0.0693, -0.0798, -0.0066, -0.0417,  0.1076,  0.0597, -0.0316,  0.0940,
#         -0.0313,  0.0993,  0.0931, -0.0427,  0.0256,  0.0297, -0.0561, -0.0155,
#         -0.0496, -0.0697, -0.1011,  0.1178,  0.0283, -0.0571, -0.0635, -0.0222,
#          0.0710, -0.0617,  0.0423, -0.0057,  0.0620, -0.0262,  0.0441,  0.0425,
#         -0.0413, -0.0245,  0.0043,  0.0185,  0.0060, -0.1727, -0.1152,  0.0655,
#         -0.0235, -0.1465, -0.1359,  0.0022,  0.0177, -0.0176, -0.0361, -0.0750,
#         -0.0464, -0.0846, -0.0088,  0.0136, -0.0221,  0.0591,  0.0876, -0.0903,
#          0.0271, -0.1165, -0.0169, -0.0566,  0.1173, -0.0801,  0.0430,  0.0236,
#          0.0060, -0.0778, -0.0570,  0.0102, -0.0172, -0.0051, -0.0891, -0.0620,
#         -0.0536,  0.0190, -0.0039, -0.0189, -0.0267, -0.0389, -0.0208,  0.0076,
#         -0.0676,  0.0630, -0.0962,  0.0418, -0.0172, -0.0229, -0.0452,  0.0401,
#          0.0270,  0.0677, -0.0111, -0.0089,  0.0175,  0.0703,  0.0714, -0.0068,
#          0.1214, -0.0004,  0.0020,  0.0255,  0.0424, -0.0030,  0.0318,  0.1227,
#          0.0676, -0.0723,  0.0970,  0.0637, -0.0140, -0.0283, -0.0120,  0.0343,
#         -0.0890,  0.0680,  0.0514,  0.0513,  0.0627, -0.0284, -0.0479,  0.0068,
#         -0.0794,  0.0202,  0.0208, -0.0113, -0.0747,  0.0045, -0.0854, -0.0609,
#         -0.0078,  0.1168,  0.0618, -0.0223, -0.0755,  0.0182, -0.0128,  0.1116,
#          0.0240,  0.0342,  0.0119, -0.0235, -0.0150, -0.0228, -0.0568, -0.1528,
#          0.0164, -0.0268,  0.0727, -0.0569,  0.1306,  0.0643, -0.0158, -0.1070,
#         -0.0107, -0.0139, -0.0363,  0.0366, -0.0986, -0.0628, -0.0277,  0.0316,
#          0.0363,  0.0038, -0.1092, -0.0679, -0.1398, -0.0648,  0.1711, -0.0666,
#          0.0563,  0.0581,  0.0226,  0.0347, -0.0672, -0.0229, -0.0565,  0.0623,
#          0.1089, -0.0687, -0.0901, -0.0073,  0.0426,  0.0870, -0.0390, -0.0144,
#         -0.0166,  0.0262, -0.0310,  0.0467, -0.0164, -0.0700, -0.0602, -0.0720,
#         -0.0386,  0.0067, -0.0337, -0.0053,  0.0829,  0.1004,  0.0427,  0.0026,
#         -0.0537,  0.0951,  0.0584, -0.0583, -0.0208,  0.0124,  0.0067,  0.0403,
#          0.0091, -0.0044, -0.0036,  0.0524,  0.1103, -0.1511, -0.0479,  0.1709,
#          0.0772,  0.0721, -0.0332,  0.0866,  0.0799, -0.0581,  0.0713,  0.0218],
#        device='cuda:0', grad_fn=<SelectBackward0>)

# %%
from sentence_transformers import SentenceTransformer

queries = ['Calculate the n-th factorial']
code_snippets = ['def fact(n):\n if n < 0:\n  raise ValueError\n return 1 if n == 0 else n * fact(n - 1)']

model = SentenceTransformer("nomic-ai/nomic-embed-code")
query_emb = model.encode(queries, prompt_name="query")
code_emb = model.encode(code_snippets)

similarity = model.similarity(query_emb[0], code_emb[0])
print(similarity)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/274 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/55.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/704 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.78G [00:00<?, ?B/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/3.66G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[14], line 6
#       3 queries = ['Calculate the n-th factorial']
#       4 code_snippets = ['def fact(n):\n if n < 0:\n  raise ValueError\n return 1 if n == 0 else n * fact(n - 1)']
# ----> 6 model = SentenceTransformer("nomic-ai/nomic-embed-code")
#       7 query_emb = model.encode(queries, prompt_name="query")
#       8 code_emb = model.encode(code_snippets)
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:367, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     364 except StopIteration:
#     365     pass
# --> 367 self.to(device)
#     368 self.is_hpu_graph_enabled = False
#     370 if self.default_prompt_name is not None and self.default_prompt_name not in self.prompts:
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1369, in Module.to(self, *args, **kwargs)
#    1366         else:
#    1367             raise
# -> 1369 return self._apply(convert)
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/torch/nn/modules/module.py:928, in Module._apply(self, fn, recurse)
#     926 if recurse:
#     927     for module in self.children():
# --> 928         module._apply(fn)
#     930 def compute_should_use_set_data(tensor, tensor_applied):
#     931     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     932         # If the new tensor has compatible tensor type as the existing tensor,
#     933         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    938         # global flag to let the user control whether they want the future
#     939         # behavior of overwriting the existing tensor or not.
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/torch/nn/modules/module.py:928, in Module._apply(self, fn, recurse)
#     926 if recurse:
#     927     for module in self.children():
# --> 928         module._apply(fn)
#     930 def compute_should_use_set_data(tensor, tensor_applied):
#     931     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     932         # If the new tensor has compatible tensor type as the existing tensor,
#     933         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    938         # global flag to let the user control whether they want the future
#     939         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 928 (3 times)]
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/torch/nn/modules/module.py:928, in Module._apply(self, fn, recurse)
#     926 if recurse:
#     927     for module in self.children():
# --> 928         module._apply(fn)
#     930 def compute_should_use_set_data(tensor, tensor_applied):
#     931     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     932         # If the new tensor has compatible tensor type as the existing tensor,
#     933         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    938         # global flag to let the user control whether they want the future
#     939         # behavior of overwriting the existing tensor or not.
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/torch/nn/modules/module.py:955, in Module._apply(self, fn, recurse)
#     951 # Tensors stored in modules are graph leaves, and we don't want to
#     952 # track autograd history of `param_applied`, so we have to use
#     953 # `with torch.no_grad():`
#     954 with torch.no_grad():
# --> 955     param_applied = fn(param)
#     956 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     958 from torch._subclasses.fake_tensor import FakeTensor
#
# File ~/indus_traning/sentense_transformers/stenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1355, in Module.to.<locals>.convert(t)
#    1348     if convert_to_format is not None and t.dim() in (4, 5):
#    1349         return t.to(
#    1350             device,
#    1351             dtype if t.is_floating_point() or t.is_complex() else None,
#    1352             non_blocking,
#    1353             memory_format=convert_to_format,
#    1354         )
# -> 1355     return t.to(
#    1356         device,
#    1357         dtype if t.is_floating_point() or t.is_complex() else None,
#    1358         non_blocking,
#    1359     )
#    1360 except NotImplementedError as e:
#    1361     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 260.00 MiB. GPU 0 has a total capacity of 23.55 GiB of which 197.19 MiB is free. Including non-PyTorch memory, this process has 23.35 GiB memory in use. Of the allocated memory 22.85 GiB is allocated by PyTorch, and 263.43 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
