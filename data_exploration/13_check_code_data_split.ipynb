# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from datasets import (
    Dataset,
    DatasetDict,
    concatenate_datasets,
    get_dataset_config_names,
    load_dataset,
    load_from_disk,
)

# load from local
data1_path = "/rhome/sawale/indus_traning/sentense_transformers/data/stage3_cache/NROWS_None/nasa-science-function-code-docstring"
data1 = load_from_disk(data1_path)

data1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['anchor', 'positive'],
#         num_rows: 1019602
#     })
#     validation: Dataset({
#         features: ['anchor', 'positive'],
#         num_rows: 56645
#     })
#     test: Dataset({
#         features: ['anchor', 'positive'],
#         num_rows: 56645
#     })
# })

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("nasa-impact/nasa-science-function-code-docstring")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'identifier', 'code', 'original_docstring', 'repo', 'path', 'language', 'URL', 'original_string'],
#         num_rows: 992719
#     })
#     test: Dataset({
#         features: ['id', 'identifier', 'code', 'original_docstring', 'repo', 'path', 'language', 'URL', 'original_string'],
#         num_rows: 140173
#     })
# })

# %%
total = 992719 + 140173

1019602 + 56645 + 56645 == total
# Out:
# True

# %%
original_df_path = "/rhome/sawale/indus_traning/sentense_transformers/gen_code_data/TheVault/data/step4/nasa_science_function_code_docstring/python"

import pandas as pd

original_df = pd.read_parquet(original_df_path)

train_df = pd.read_parquet("/rhome/sawale/indus_traning/sentense_transformers/gen_code_data/TheVault/data/step4/nasa_science_function_code_docstring/python/train.parquet")
eval_df = pd.read_parquet("/rhome/sawale/indus_traning/sentense_transformers/gen_code_data/TheVault/data/step4/nasa_science_function_code_docstring/python/eval.parquet")
test_df = pd.read_parquet("/rhome/sawale/indus_traning/sentense_transformers/gen_code_data/TheVault/data/step4/nasa_science_function_code_docstring/python/test.parquet")
train_df.shape, test_df.shape, eval_df.shape, original_df.shape
# Out:
# ((319074, 9), (37261, 9), (54827, 9), (411162, 9))

# %%
total = 411162
from_hf = 319074 + 92088
in_cache = 370045 + 20558 + 20559

in_cache
# Out:
# 411162

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("nasa-impact/nasa-science-class-code-identifier")
# Out:
# train.parquet:   0%|          | 0.00/132M [00:00<?, ?B/s]
# eval.parquet:   0%|          | 0.00/15.0M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'identifier', 'code', 'original_docstring', 'repo', 'path', 'language', 'URL', 'original_string'],
#         num_rows: 50284
#     })
#     test: Dataset({
#         features: ['id', 'identifier', 'code', 'original_docstring', 'repo', 'path', 'language', 'URL', 'original_string'],
#         num_rows: 5449
#     })
# })
