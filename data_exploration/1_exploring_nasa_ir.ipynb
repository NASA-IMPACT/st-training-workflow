# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from datasets import load_dataset
from huggingface_hub import hf_hub_download
import json
import pandas as pd


dataset = load_dataset("nasa-impact/nasa-smd-IR-benchmark")
val_df = dataset["validation"].to_pandas()
test_df = dataset["test"].to_pandas()

# Download queries.jsonl from the dataset repo
queries_path = hf_hub_download(
    repo_id="nasa-impact/nasa-smd-IR-benchmark",
    filename="queries.jsonl",
    repo_type="dataset"
)

# Download corpus.jsonl similarly
corpus_path = hf_hub_download(
    repo_id="nasa-impact/nasa-smd-IR-benchmark",
    filename="corpus.jsonl",
    repo_type="dataset"
)

queries_df = pd.read_json(queries_path, lines=True)
queries_df.rename(columns={"_id": "query-id", "text": "query"}, inplace=True)

corpus_df = pd.read_json(corpus_path, lines=True)
corpus_df.rename(columns={"_id": "corpus-id", "text": "corpus"}, inplace=True)

# Join for validation set
val_df = val_df.merge(queries_df, on="query-id", how="left")
val_df = val_df.merge(corpus_df, on="corpus-id", how="left")

# Join for test set
test_df = test_df.merge(queries_df, on="query-id", how="left")
test_df = test_df.merge(corpus_df, on="corpus-id", how="left")

# %%
val_df
# Out:
#     query-id  corpus-id  score  \
# 0         67      72915      1
# 1        239      37223      1
# 2        495     250048      1
# 3        283     125841      1
# 4        200     213374      1
# ..       ...        ...    ...
# 95        61      18475      1
# 96       197     115182      1
# 97        81     198092      1
# 98       249     118331      1
# 99       133      34741      1
#
#                                                 query title  \
# 0                 What does the Mann-Kendall test do?
# 1        What complicates the theory of the observer?
# 2   What are the two mechanisms regarding the move...
# 3   Can solid monolithic "rocky" bodies shed a dus...
# 4   Besides being born in or from a circumplanetar...
# ..                                                ...   ...
# 95  The equilibrium models and some dynamic vegeta...
# 96  What surface and thermodynamical processes are...
# 97  AN pollution in mine soil is becoming a seriou...
# 98  Over what wavelength range was IRIS used to ob...
# 99  Which instrument is on the Suomi National Pola...
#
#                                                corpus
# 0   Apart from groundwater mentioned in the above ...
# 1   Every careful observer of this magnificent pla...
# 2   We present a novel mathematical formalism to p...
# 3   Related to the morphology, it is the tensile s...
# 4   The low orbital inclinations of Phobos and Dei...
# ..                                                ...
# 95  It is likely that changing temperature and pre...
# 96  Recently, numerically sophisticated general ci...
# 97  The problem of AN pollution in mine soil is be...
# 98  At longer wavelengths, Miranda and Ariel were ...
# 99  We present a near surface air temperature (NSA...
#
# [100 rows x 6 columns]
