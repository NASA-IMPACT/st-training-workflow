# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from datasets import get_dataset_config_names

# ← NO trust_remote_code here
configs = get_dataset_config_names("BeIR/beir")
print(configs)
# Out:
# ['fiqa', 'trec-covid', '']

# %%
from datasets import get_dataset_config_names, load_dataset

# 1. (Optional) see which configs are available
configs = get_dataset_config_names("raw/beir.py", trust_remote_code=True)

configs
# Out:
# ['msmarco',
#  'nfcorpus',
#  'fiqa',
#  'trec-covid',
#  'nq',
#  'hotpotqa',
#  'arguana',
#  'webis-touche2020',
#  'cqadupstack',
#  'quora',
#  'dbpedia-entity',
#  'scidocs',
#  'fever',
#  'climate-fever',
#  'scifact']

# %%
from datasets import load_dataset


_datasets = ["msmarco", "nfcorpus", "fiqa", "trec-covid", "nq", "hotpotqa", "arguana", "webis-touche2020", "cqadupstack", "quora", "dbpedia-entity", "scidocs", "fever", "climate-fever", "scifact"]


for dname in _datasets:
    configs = load_dataset(f"/rhome/sawale/indus_traning/sentense_transformers/data_exploration/raw/beir.py", dname, trust_remote_code=True)
    print(configs)

# this will fetch the script and the data for you automatically
ds = load_dataset("/rhome/sawale/indus_traning/sentense_transformers/data_exploration/raw/beir.py", "scifact", trust_remote_code=True)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['query', 'relevant'],
#         num_rows: 809
#     })
#     test: Dataset({
#         features: ['query', 'relevant'],
#         num_rows: 300
#     })
# })
